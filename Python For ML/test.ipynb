# %%
print("Hello, World!")
for i in "Sami":
    print(i)
name = input("Press Enter to exit...")
print(name)
# Out:
# Hello, World!
# S
# a
# m
# i
# sami

# %%
stack = []
for i in range(1,4):
    stack.append(i)
stack.pop()
print(stack[-1])
# Out:
# 2

# %%
queue = [10, 20, 30,40]
queue.pop(1)
print(queue)
queue.append(50)
print(queue)
queue.pop(0)
print(queue[0])
# Out:
# [10, 30, 40]
# [10, 30, 40, 50]
# 30

# %%
x = [1, 2, 3 , 2 , 4]
x.remove(4)
x.pop()
print(x)
# Out:
# [1, 2, 3]
