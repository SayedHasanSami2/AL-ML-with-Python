# %%
x = input()  #e.g. "13 12"

numbers = x.split() #splits the input string into a list of substrings based on spaces

x = int(numbers[0])   #13
y = int(numbers[1])   #12

sum = (x % 10 + y % 10)
print(sum)
# Out:
# 5

# %%
stack = []
stack.append(1) 
stack.append(2)
stack.append(3)
stack.append(4)
print(stack)  #[1, 2, 3, 4]
print(stack.pop())
print(stack.pop())
print(stack.pop())
# Out:
# [1, 2, 3, 4]
# 4
# 3
# 2
