# %%
with open("sample.txt", "r") as file:
    for line in file:
        line = line.strip()
        print(line)
# Out:
# Hi
# This is Sayed Hasan Sami

# %%
with open("sample.txt", "w") as file:
    file.write("New content added to the file.\n")
    file.write("Another line of content.\n")
